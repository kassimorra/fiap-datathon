# %% [markdown]
# # Load Data -dataGlobo

# %%
import psycopg2
import pandas as pd

# %%
userid = "42d36d52af66f05d08a884de5ca1341b9db35b5fcbb81729701e429e832579fe"
sql_query = f"select * from table_full where userid = '{userid}' order by timestamphistory desc"

# %%
conn = psycopg2.connect(
            dbname="globo",
            user="postgres",
            password="admin1234",
            host="localhost",
            port="5432"
        )
user_data = pd.read_sql(sql_query, conn)
conn.close()
# Out:
# C:\Users\felip\AppData\Local\Temp\ipykernel_21924\2154098811.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   user_data = pd.read_sql(sql_query, conn)

# %%
user_data.head(50)
# Out:
#                                                userid    usertype  \
# 0   42d36d52af66f05d08a884de5ca1341b9db35b5fcbb817...  Non-Logged
# 1   42d36d52af66f05d08a884de5ca1341b9db35b5fcbb817...  Non-Logged
# 2   42d36d52af66f05d08a884de5ca1341b9db35b5fcbb817...  Non-Logged
# 3   42d36d52af66f05d08a884de5ca1341b9db35b5fcbb817...  Non-Logged
# 4   42d36d52af66f05d08a884de5ca1341b9db35b5fcbb817...  Non-Logged
# 5   42d36d52af66f05d08a884de5ca1341b9db35b5fcbb817...  Non-Logged
# 6   42d36d52af66f05d08a884de5ca1341b9db35b5fcbb817...  Non-Logged
# 7   42d36d52af66f05d08a884de5ca1341b9db35b5fcbb817...  Non-Logged
# 8   42d36d52af66f05d08a884de5ca1341b9db35b5fcbb817...  Non-Logged
# 9   42d36d52af66f05d08a884de5ca1341b9db35b5fcbb817...  Non-Logged
# 10  42d36d52af66f05d08a884de5ca1341b9db35b5fcbb817...  Non-Logged
# 11  42d36d52af66f05d08a884de5ca1341b9db35b5fcbb817...  Non-Logged
# 12  42d36d52af66f05d08a884de5ca1341b9db35b5fcbb817...  Non-Logged
# ...

# %% [markdown]
# Última notícias disponível: 2023-06-16 17:19:15
# Inferência de matérias: (Lista de notícias recentes) - (Notícias já lidas)
